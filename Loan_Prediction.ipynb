# %% [markdown]
# # Predict Loan Eligibility for Dream Housing Finance company

# %% [markdown]
# Dream Housing Finance company deals in all kinds of home loans. They have presence across all urban, semi urban and rural areas. Customer first applies for home loan and after that company validates the customer eligibility for loan.
#
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have provided a dataset to identify the customers segments that are eligible for loan amount so that they can specifically target these customers.

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# **Train file:** CSV containing the customers for whom loan eligibility is known as 'Loan_Status'

# %% [markdown]
# <table style="border: none; border-collapse: collapse; width: 437pt;">
#     <tbody>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border: 0.5pt solid windowtext; height: 16pt; width: 144pt;">
#                 <b>
#                     Variable</td></b>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-top: 0.5pt solid windowtext; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-left: none; width: 293pt; min-width: 5px; user-select: text;     ">
#                 <b>
#                     Description
#                 </b>
#             </td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_ID</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Unique Loan ID</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Gender</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Male/ Female</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Married</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant married (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Dependents</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Number of dependents</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Education</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant Education (Graduate/ Under Graduate)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Self_Employed</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Self employed (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 ApplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 CoapplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Coapplicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 LoanAmount</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Loan amount in thousands</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Amount_Term</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Term of loan in months</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Credit_History</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 credit history meets guidelines</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Property_Area</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Urban/ Semi Urban/ Rural</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Status</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 (Target) Loan approved (Y/N)</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# **Test file:** CSV containing the customer information for whom loan eligibility is to be predicted

# %% [markdown]
# <table style="border: none; border-collapse: collapse; width: 437pt;    ">
#     <tbody>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border: 0.5pt solid windowtext; height: 16pt; width: 144pt;     ">
#                 <b>Variable</b></td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-top: 0.5pt solid windowtext; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-left: none; width: 293pt; min-width: 5px; user-select: text;     ">
#                 <b>Description</b></td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_ID</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Unique Loan ID</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Gender</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Male/ Female</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Married</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant married (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Dependents</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Number of dependents</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Education</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant Education (Graduate/ Under Graduate)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Self_Employed</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Self employed (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 ApplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 CoapplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Coapplicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 LoanAmount</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Loan amount in thousands</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Amount_Term</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Term of loan in months</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Credit_History</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 credit history meets guidelines</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Property_Area</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Urban/ Semi Urban/ Rural</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Python Code

# %%
import pandas as pd
import math
import os
import re
import keras
from keras.models import Sequential
from keras.layers import Dense
# from scikeras.wrappers import KerasClassifier, KerasRegressor
import numpy as np
import statsmodels.api as sm
from statsmodels.tools import add_constant as ac
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder, Binarizer
sc = StandardScaler()
le = LabelEncoder()
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report,  mean_squared_error, ConfusionMatrixDisplay

from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
rfr = RandomForestClassifier()
# from pyforest import *
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')
from sklearn.svm import SVR
from statsmodels.formula.api import ols
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
train.shape
# Out:
# (614, 13)

# %%
for i in train.columns:
    if i not in test.columns:
        target_var = i
target_var
# Out:
# 'Loan_Status'

# %%
# This function would return the last created submission file with the name 
# provided(x), so that the next submission file would be named with the next 
# number automatically. 
# Like Sub1, Sub2.  

def ret_latest_file(x):
    ans = os.listdir()
    finlist = []
    re_pat = re.compile("([a-zA-Z]+)([0-9]+)")
    for i in ans:
        try:            
            if i[-3:] == 'csv':
                res = re_pat.match(i).groups()                
                if res[0] == x:
                    finlist.append(int(res[1]))            
        except:
            pass
    if len(finlist) > 0:
        return x, max(finlist)
    else:
        return x, 0

# %%
# Preparing Data for submission

def sub(n, pred):
    name, num = ret_latest_file(n)
    sol = pd.read_csv('sample_submission.csv')
    sol.loc[:, target_var] = pred
    sol.to_csv(name + '{}.csv'.format(num+1), index=False)

# %%
# Splitting combined into x_train, x_test, y_train, y_test

def split_data(df, y = target_var):

    x_train = df[df[y].notnull()]
    x_train.drop(y, inplace=True, axis=1)

    x_test = df[df[y].isnull()]
    x_test.drop(y, inplace=True, axis=1)
    y_train = df[df[y].notnull()][y]

    y_test = df[df[y].isna()][y]

    return x_train, x_test, y_train, y_test

# %%
# Implementing SMOTE

def smote(x, y):
    oversample = SMOTE(random_state = 2, sampling_strategy='minority')
    x = x.values
    y = y.values
    x, y = oversample.fit_resample(x, y)
    return x, y

# %%
# Implementing NearMiss

def near_miss(x, y):
    nr = NearMiss() 
    x_near, y_near= nr.fit_resample(x, y)
    return x_near, y_near

# %%
def cm_data(cm):
    tn = cm[0, 0]
    fp = cm[0, 1]
    fn = cm[1, 0]
    tp = cm[1, 1]
    print("Sensitivity: ", tp/(tp+fn))
    print("Specificity: ",tn/(tn+fp))
    print("Precision: ", tp/(tp+fp))
    print("Accuracy: ", (tp+tn)/(tp+tn+fp+fn))

# %%
def check_accuracy(test, pred, conf_mat = 'no'):
    acc = accuracy_score(test, pred)
    if conf_mat == 'yes':
        cm = confusion_matrix(test, pred)
        cm_df = pd.DataFrame(cm, columns=['Pred: 0', 'Pred: 1'], index = ['Obs: 0', 'Obs: 1'])
        # plt.figure(figsize=(10, 10))
        sns.heatmap(cm_df, annot=True, fmt='d')
        plt.show()
        cm_data(cm)
    return acc

# %%
def rand_search(model, params, df, samp = None, cm = 'no', subm = 'no'):

    x_train, x_test, y_train, y_test = split_data(df)
    # print(y_train.value_counts())

    if samp != None:
        if samp == 'o':
            x_train, y_train = smote(x_train, y_train)
        elif samp == 'u':
            x_train, y_train = near_miss(x_train, y_train)
        elif samp == 'b':
            x_train, y_train = smote(x_train, y_train)
            x_train, y_train = near_miss(x_train, y_train)
        x_train = pd.DataFrame(x_train)
        y_train = pd.DataFrame(y_train, columns=['Loan_Status'])

    # print(y_train.value_counts())
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=123)     
    # print(y_train.value_counts())

    x_train = sc.fit_transform(x_train)
    x_test = sc.transform(x_test)

    grid_mod = RandomizedSearchCV(model, param_distributions=params, scoring = ['accuracy', 'f1'], cv = 10, n_jobs=-1, refit='accuracy')
    grid_mod.fit(x_train, y_train)

    if cm == 'yes':
        y_val_pred = grid_mod.predict(x_val)
        acc = check_accuracy(y_val, y_val_pred, conf_mat = 'yes')
    
    if subm == 'yes':
        y_pred = grid_mod.predict(x_test)
        sub(str(model)[:4], y_pred)

    return grid_mod.best_estimator_, acc

# %%
combined = pd.concat([train, test], sort=False, ignore_index=True)
combined.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             957 non-null    object
#  2   Married            978 non-null    object
#  3   Dependents         956 non-null    object
#  4   Education          981 non-null    object
#  5   Self_Employed      926 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    float64
#  10  Credit_History     902 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 99.8+ KB

# %%
# Credit History and Loan_Amount_Term should be categorical

to_be_cat = ["Credit_History", "Loan_Amount_Term"]
obj_data = list(combined.select_dtypes(['object']))
for i in obj_data:
    to_be_cat.append(i)
combined[to_be_cat] = combined[to_be_cat].astype('category')
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    category
#  1   Gender             957 non-null    category
#  2   Married            978 non-null    category
#  3   Dependents         956 non-null    category
#  4   Education          981 non-null    category
#  5   Self_Employed      926 non-null    category
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    category
#  10  Credit_History     902 non-null    category
#  11  Property_Area      981 non-null    category
#  12  Loan_Status        614 non-null    category
# dtypes: category(10), float64(2), int64(1)
# memory usage: 75.0 KB

# %%
# Base Submission
 
# sub("Base", "Y")

# %% [markdown]
# ### Univariate Analysis

# %%
not_to_plot = ["Loan_ID"]
color = ['r', 'g', 'b']

# %%
def univariate(df = combined, rows = 4, cols = 4):
    fig=plt.figure(figsize=(20,20))
    for j, i in enumerate(df.columns):
        if i not in not_to_plot:
            ax=fig.add_subplot(rows,cols,j+1)
            if i in df.select_dtypes(['category', 'object']):
                sns.countplot(x= i, data = df, ax=ax)
                plt.xticks(rotation = 90)
            if i in df.select_dtypes(['int', 'float64']):
                sns.distplot(x = df[i], ax=ax, color=np.random.choice(color))
                ax.set(xlabel=i)
    fig.tight_layout() 
    plt.show()

# %%
univariate()

# %% [markdown]
# #### Insights:
#
# 1. In **Loan Status** column, high Imbalance exists. Could try Balancing it with *SMOTE*.
# 2. In **Loan Amount Term** column, Maximum People(800) are taking loan for 30 years (360 months). Could be Huge loans like Car loans or Home Loans.
# 3. In **Gender** column, Male Applicants are quite higher than Female Applicants.
#
#     3.1 Male Applicants could be from Urban, Semi Urban and Rural areas.
#
#     3.2 Female Applicants could be just from Urban Areas.

# %% [markdown]
# ### Bivariate Analysis

# %%
def bivariate(df = combined, y = target_var, cols = 4, rows = 3):
    temp = not_to_plot[:]
    temp.append(y)
    fig=plt.figure(figsize=(25,20))

    for j, i in enumerate(df.columns):
        if i not in temp:
            if df[y].dtype == 'float':
                if i in df.select_dtypes(['category', 'object']):
                    if (i not in temp): 
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.boxplot(x = i, y = y, data = df)
                        plt.xticks(rotation = 90)

                if i in df.select_dtypes(['float', 'int']):                
                    if (i not in temp):      
                        ax=fig.add_subplot(rows,cols,j+1)       
                        sns.scatterplot(x = y, y = i, data = df)                  
                
            elif df[y].dtype == 'category':
                if i in df.select_dtypes(['category', 'object']):
                    if (i not in temp):
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.countplot(x = i, hue = y, data = df)
                        plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
                        plt.xticks(rotation = 90)

                if i in df.select_dtypes(['float', 'int']):
                    if (i not in temp):
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.boxplot(x = y, y = i, data = df)
                        plt.xticks(rotation = 90)
    fig.tight_layout() 
    plt.show()

# %%
bivariate()

# %% [markdown]
# ### Missing Values

# %%
combined.isnull().sum()[combined.isnull().sum()>0]
# Out:
# Gender               24
# Married               3
# Dependents           25
# Self_Employed        55
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Loan_Status         367
# dtype: int64

# %% [markdown]
# #### Solution 1: Drop All Null Values and Create a model.

# %%
# combined.dropna(subset= combined.columns[combined.columns != target_var], inplace=True)

# %%
combined.isnull().sum()[combined.isnull().sum()>0]
# Out:
# Gender               24
# Married               3
# Dependents           25
# Self_Employed        55
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Loan_Status         367
# dtype: int64

# %%
combined["Gender"].isnull().sum()
# Out:
# 24

# %% [markdown]
# Dropping Null Values leads to removal of some Test data.
#
# Can't Drop Null Values.

# %% [markdown]
# #### Solution 2: Fill All Null Values with Mean, Mode of the columns.

# %%
def fill_na(df = combined):
    for i in df.columns:
        if i != target_var:
            if df[i].isnull().sum() > 0:
                if i in df.select_dtypes(["category", "object"]):
                    df[i].fillna(df.mode()[i][0], inplace = True)
                elif i in df.select_dtypes(["int", "float"]):
                    df[i].fillna(df[i].mean(), inplace = True)
    print(df.isnull().sum()[df.isnull().sum()>0])
    return df

# %%
combined = fill_na()
# Out:
# Loan_Status    367
# dtype: int64

# %% [markdown]
# #### Solution 3: Find Pattern for all columns and fill null values.

# %% [markdown]
# ##### Gender - 24

# %%
combined[combined.Gender.isnull()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
bivariate(y = "Gender", rows = 4)

# %% [markdown]
# ### Feature Engineering

# %%
combined.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 660  LP001237    Male     Yes          0  Not Graduate            No
# 298  LP001955  Female      No          0      Graduate            No
# 440  LP002408    Male      No          0      Graduate            No
# 715  LP001542  Female     Yes          0      Graduate            No
# 334  LP002103    Male     Yes          1      Graduate           Yes
# 672  LP001323  Female     Yes          2      Graduate            No
# 280  LP001910    Male      No          1  Not Graduate           Yes
# 571  LP002847    Male     Yes          0      Graduate            No
# 64   LP001222  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 25              9560                0.0   191.00000            360.0
# 660             4163             1475.0   162.00000            360.0
# 298             5000             2541.0   151.00000            480.0
# 440             3660             5064.0   187.00000            360.0
# 715             2262                0.0   142.51153            480.0
# 334             9833             1833.0   182.00000            180.0
# 672             2779             3664.0   176.00000            360.0
# 280             4053             2426.0   158.00000            360.0
# 571             5116             1451.0   165.00000            360.0
# 64              4166                0.0   116.00000            360.0
#
#     Credit_History Property_Area Loan_Status
# 25             1.0     Semiurban           Y
# 660            1.0         Urban         NaN
# 298            1.0         Rural           N
# 440            1.0     Semiurban           Y
# 715            0.0     Semiurban         NaN
# 334            1.0         Urban           Y
# 672            0.0     Semiurban         NaN
# 280            0.0         Urban           N
# 571            0.0         Urban           N
# 64             0.0     Semiurban           N

# %%
combined_feat = combined[:]

# %%
# Could try adding Applicant Income and Co-Applicant Income to create Household Income.

combined_feat['House_Income'] = combined_feat["ApplicantIncome"] + combined_feat["CoapplicantIncome"] 
combined_feat.drop(["ApplicantIncome", "CoapplicantIncome"], axis = 1, inplace=True)
combined_feat.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 742  LP001667    Male      No          0      Graduate            No
# 769  LP001857    Male      No          0  Not Graduate           Yes
# 366  LP002187    Male      No          0      Graduate            No
# 207  LP001698    Male      No          0  Not Graduate            No
# 135  LP001488    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 206  LP001693  Female      No          0      Graduate            No
# 662  LP001268    Male      No          0      Graduate            No
# 920  LP002721    Male     Yes          2      Graduate           Yes
# 487  LP002547    Male     Yes          1      Graduate            No
#
#      LoanAmount Loan_Amount_Term Credit_History Property_Area Loan_Status  \
# 742        70.0            180.0            1.0         Urban         NaN
# 769       125.0            300.0            1.0     Semiurban         NaN
# 366        96.0            480.0            1.0     Semiurban           N
# 207        55.0            360.0            1.0         Rural           Y
# 135       290.0            360.0            1.0     Semiurban           N
# 213       130.0            360.0            1.0         Rural           Y
# 206        80.0            360.0            1.0         Urban           Y
# 662       187.0            360.0            1.0         Urban         NaN
# 920       183.0            360.0            1.0         Rural         NaN
# 487       500.0            360.0            1.0         Urban           N
#
#      House_Income
# 742        3073.0
# 769        4073.0
# 366        2500.0
# 207        6506.0
# 135       11750.0
# 213        5703.0
# 206        3244.0
# 662       10130.0
# 920        7500.0
# 487       18333.0

# %%
combined.Loan_Amount_Term.value_counts()
# Out:
# 360.0    843
# 180.0     66
# 480.0     23
# 300.0     20
# 240.0      8
# 84.0       7
# 120.0      4
# 36.0       3
# 60.0       3
# 12.0       2
# 6.0        1
# 350.0      1
# Name: Loan_Amount_Term, dtype: int64

# %%
# Could try converting Term into years.
from numpy import int64

combined_feat["Loan_Amount_Term"] = combined_feat["Loan_Amount_Term"].astype(int64)
combined_feat["Loan_Term"] = combined_feat["Loan_Amount_Term"] / 12
combined_feat.drop(["Loan_Amount_Term"], axis = 1, inplace=True)
combined_feat["Loan_Term"] = combined_feat["Loan_Term"].astype(int64)
combined_feat["Loan_Term"] = combined_feat["Loan_Term"].astype("category")
combined_feat.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  LoanAmount  \
# 193  LP001658    Male      No          0  Graduate            No        76.0
# 294  LP001947    Male     Yes          0  Graduate            No       172.0
# 165  LP001574    Male     Yes          0  Graduate            No       182.0
# 106  LP001369    Male     Yes          2  Graduate            No       225.0
# 181  LP001634    Male      No          0  Graduate            No        67.0
# 97   LP001333    Male     Yes          0  Graduate            No        50.0
# 199  LP001673    Male      No          0  Graduate           Yes        83.0
# 306  LP001993  Female      No          0  Graduate            No       135.0
# 465  LP002494    Male      No          0  Graduate            No       140.0
# 146  LP001516  Female     Yes          2  Graduate            No        70.0
#
#     Credit_History Property_Area Loan_Status  House_Income Loan_Term
# 193            1.0     Semiurban           Y        3858.0        30
# 294            1.0     Semiurban           Y        5717.0        30
# 165            1.0         Rural           Y        6873.0        30
# 106            1.0         Urban           Y       12543.0        30
# 181            1.0         Rural           N        6979.0        30
# 97             1.0     Semiurban           Y        2974.0        30
# 199            1.0         Urban           N       11000.0        30
# 306            1.0         Rural           Y        5428.0        30
# 465            1.0         Rural           Y        6000.0        30
# 146            1.0         Urban           Y       14866.0        30

# %%
combined_feat.drop(["Loan_ID"], axis = 1, inplace=True)
combined_feat.sample(10)
# Out:
#     Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 915   Male     Yes          1      Graduate            No       125.0
# 3     Male     Yes          0  Not Graduate            No       120.0
# 696   Male     Yes          2  Not Graduate            No       149.0
# 920   Male     Yes          2      Graduate           Yes       183.0
# 462   Male     Yes          0      Graduate            No       153.0
# 816   Male     Yes          0      Graduate            No       100.0
# 161   Male     Yes          0      Graduate            No       275.0
# 921   Male     Yes          2  Not Graduate            No       121.0
# 675   Male     Yes          0      Graduate           Yes       125.0
# 130   Male      No          0      Graduate           Yes       650.0
#
#     Credit_History Property_Area Loan_Status  House_Income Loan_Term
# 915            0.0         Urban         NaN        6300.0        30
# 3              1.0         Urban           Y        4941.0        30
# 696            0.0         Rural         NaN        4136.0        40
# 920            1.0         Rural         NaN        7500.0        30
# 462            1.0         Rural           Y        5203.0        30
# 816            1.0         Urban         NaN        4316.0        30
# 161            1.0         Urban           N        7933.0        30
# 921            1.0         Rural         NaN        3859.0        30
# 675            1.0         Urban         NaN        7308.0        30
# 130            1.0         Urban           Y       20166.0        40

# %% [markdown]
# #### Encoding

# %%
combined_en = combined_feat[:]

# %% [markdown]
# ##### Label Encoding

# %%
lb_en = ["Loan_Term"]

# %%
combined_en[lb_en] = combined_en[lb_en].apply(LabelEncoder().fit_transform)
combined_en.sample(5)
# Out:
#     Gender Married Dependents Education Self_Employed  LoanAmount  \
# 235   Male     Yes          1  Graduate            No       170.0
# 642   Male     Yes          0  Graduate            No        57.0
# 615   Male     Yes          1  Graduate            No       126.0
# 832   Male     Yes          1  Graduate           Yes       212.0
# 965   Male      No          0  Graduate            No       106.0
#
#     Credit_History Property_Area Loan_Status  House_Income  Loan_Term
# 235            1.0         Rural           Y        6760.0         10
# 642            1.0     Semiurban         NaN        4605.0         10
# 615            1.0         Urban         NaN        4576.0         10
# 832            1.0         Rural         NaN        6655.0         10
# 965            1.0         Rural         NaN       17283.0         10

# %%
combined_en.replace(to_replace = {'Y': 1, 'N': 0}, inplace = True)

# %%
combined_en.Loan_Status.value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %% [markdown]
# ##### Get Dummies

# %%
gd_dm = ["Gender", "Married", "Dependents", "Education", "Self_Employed", "Credit_History", "Property_Area"]

# %%
combined_en = pd.get_dummies(data = combined_en, columns = gd_dm, drop_first=True)
combined_en.sample(5)
# Out:
#      LoanAmount Loan_Status  House_Income  Loan_Term  Gender_Male  \
# 623       123.0         NaN        4800.0         10            1
# 78        180.0           0        7167.0          8            1
# 207        55.0           1        6506.0         10            1
# 132        70.0           1        2718.0         10            1
# 961        70.0         NaN        2868.0         10            1
#
#      Married_Yes  Dependents_1  Dependents_2  Dependents_3+  \
# 623            0             0             0              0
# 78             1             0             0              1
# 207            0             0             0              0
# 132            0             0             0              0
# 961            0             0             0              0
#
#      Education_Not Graduate  Self_Employed_Yes  Credit_History_1.0  \
# 623                       1                  0                   1
# 78                        0                  0                   0
# 207                       1                  0                   1
# 132                       0                  0                   1
# 961                       1                  0                   1
#
#      Property_Area_Semiurban  Property_Area_Urban
# 623                        1                    0
# 78                         1                    0
# 207                        0                    0
# 132                        1                    0
# 961                        0                    1

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### 1. Logistic Regression

# %%
x = combined_en.loc[combined_en["Loan_Status"].notnull(), combined_en.columns != target_var]
y = combined_en.loc[combined_en["Loan_Status"].notnull(), target_var]

model = sm.Logit(y, ac(x))
res = model.fit()

print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.456834
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            Loan_Status   No. Observations:                  614
# Model:                          Logit   Df Residuals:                      600
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 05 Sep 2022   Pseudo R-squ.:                  0.2647
# Time:                        17:55:15   Log-Likelihood:                -280.50
# converged:                       True   LL-Null:                       -381.45
# Covariance Type:            nonrobust   LLR p-value:                 5.566e-36
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -2.7773      0.958     -2.900      0.004      -4.654      -0.900
# LoanAmount                 -0.0016      0.002     -0.995      0.320      -0.005       0.002
# House_Income             -4.83e-06   2.23e-05     -0.217      0.828   -4.85e-05    3.88e-05
# Loan_Term                  -0.0138      0.079     -0.173      0.862      -0.169       0.142
# Gender_Male                -0.0459      0.296     -0.155      0.877      -0.626       0.534
# Married_Yes                 0.5838      0.251      2.322      0.020       0.091       1.077
# Dependents_1               -0.4334      0.293     -1.480      0.139      -1.007       0.141
# Dependents_2                0.2759      0.342      0.808      0.419      -0.394       0.946
# Dependents_3+               0.0481      0.419      0.115      0.909      -0.773       0.869
# Education_Not Graduate     -0.3832      0.258     -1.484      0.138      -0.890       0.123
# Self_Employed_Yes           0.0126      0.316      0.040      0.968      -0.606       0.631
# Credit_History_1.0          3.9181      0.420      9.327      0.000       3.095       4.741
# Property_Area_Semiurban     0.9117      0.270      3.381      0.001       0.383       1.440
# Property_Area_Urban         0.2288      0.259      0.883      0.377      -0.279       0.736
# ===========================================================================================

# %%
# Removing cols with p-value more than 0.05

def back_feat_elem(df = combined_en, y = target_var):
    x = df.loc[combined_en["Loan_Status"].notnull(), df.columns != y]
    y = df.loc[combined_en["Loan_Status"].notnull(), y]

    # x = x.apply(LabelEncoder().fit_transform)

    col = x.columns

    while len(col) > 0:
        model = sm.Logit(y, ac(x[col]))
        result = model.fit(disp= 0)
        largest_pvalue = round(result.pvalues, 3).nlargest(1)
        if largest_pvalue[0] < (0.05):
            return result
            break
        else:
            col = col.drop(largest_pvalue.index)

# %%
back_res = back_feat_elem()
back_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            Loan_Status   No. Observations:                  614
# Model:                          Logit   Df Residuals:                      610
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 05 Sep 2022   Pseudo R-squ.:                  0.2535
# Time:                        17:55:16   Log-Likelihood:                -284.76
# converged:                       True   LL-Null:                       -381.45
# Covariance Type:            nonrobust   LLR p-value:                 1.144e-41
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -3.1511      0.442     -7.131      0.000      -4.017      -2.285
# Married_Yes                 0.5358      0.215      2.493      0.013       0.115       0.957
# Credit_History_1.0          3.8850      0.415      9.352      0.000       3.071       4.699
# Property_Area_Semiurban     0.7860      0.232      3.386      0.001       0.331       1.241
# ===========================================================================================
# """

# %% [markdown]
# #### 2. Decision Tree Classifier

# %%
params_dt = {
    'criterion': ['gini','entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [3, 6, 9],
    'min_samples_leaf': [5, 8, 11],
    'max_features': ['sqrt', 'log2'],
}

# %%
mod_dt_o, acc_dt_o = rand_search(model = DecisionTreeClassifier(), params = params_dt, df = combined_en, cm = 'yes', samp = 'o')
# Out:
# Sensitivity:  0.17045454545454544
# Specificity:  0.8024691358024691
# Precision:  0.4838709677419355
# Accuracy:  0.47337278106508873

# %% [markdown]
# #### 3. Random Forest Classifier

# %%
rf_params = {
    'n_estimators': [10, 50, 100, 150, 200],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [10, 15, 20, 25, 40],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True, False],
    'oob_score': [True],
    'n_jobs': [3],
}

# %%
mod_rf_o, acc_rf_o = rand_search(model=RandomForestClassifier(), params=rf_params, df = combined_en, samp='o', cm='yes')
# Out:
# Sensitivity:  0.0
# Specificity:  1.0
# Precision:  nan
# Accuracy:  0.47928994082840237

# %% [markdown]
# #### 4. KNN Classification

# %%
params_knn = {
    'n_neighbors': [1, 3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'n_jobs': [-1],
    'p':[0,1,2,i]
}

# %%
mod_knn_o, acc_knn_o = rand_search(model = KNeighborsClassifier(), params = params_knn, df = combined_en, cm='yes', samp = 'o')
# Out:
# Sensitivity:  0.9545454545454546
# Specificity:  0.19753086419753085
# Precision:  0.5637583892617449
# Accuracy:  0.591715976331361
