# %% [markdown]
# # Predict Loan Eligibility for Dream Housing Finance company

# %% [markdown]
# Dream Housing Finance company deals in all kinds of home loans. They have presence across all urban, semi urban and rural areas. Customer first applies for home loan and after that company validates the customer eligibility for loan.
#
# Company wants to automate the loan eligibility process (real time) based on customer detail provided while filling online application form. These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have provided a dataset to identify the customers segments that are eligible for loan amount so that they can specifically target these customers.

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# **Train file:** CSV containing the customers for whom loan eligibility is known as 'Loan_Status'

# %% [markdown]
# <table style="border: none; border-collapse: collapse; width: 437pt;">
#     <tbody>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border: 0.5pt solid windowtext; height: 16pt; width: 144pt;">
#                 <b>
#                     Variable</td></b>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-top: 0.5pt solid windowtext; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-left: none; width: 293pt; min-width: 5px; user-select: text;     ">
#                 <b>
#                     Description
#                 </b>
#             </td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_ID</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Unique Loan ID</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Gender</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Male/ Female</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Married</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant married (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Dependents</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Number of dependents</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Education</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant Education (Graduate/ Under Graduate)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Self_Employed</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Self employed (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 ApplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 CoapplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Coapplicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 LoanAmount</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Loan amount in thousands</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Amount_Term</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Term of loan in months</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Credit_History</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 credit history meets guidelines</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Property_Area</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Urban/ Semi Urban/ Rural</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Status</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 (Target) Loan approved (Y/N)</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# **Test file:** CSV containing the customer information for whom loan eligibility is to be predicted

# %% [markdown]
# <table style="border: none; border-collapse: collapse; width: 437pt;    ">
#     <tbody>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border: 0.5pt solid windowtext; height: 16pt; width: 144pt;     ">
#                 <b>Variable</b></td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 700; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-top: 0.5pt solid windowtext; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-left: none; width: 293pt; min-width: 5px; user-select: text;     ">
#                 <b>Description</b></td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_ID</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Unique Loan ID</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Gender</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Male/ Female</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Married</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant married (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Dependents</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Number of dependents</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Education</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant Education (Graduate/ Under Graduate)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Self_Employed</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Self employed (Y/N)</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 ApplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Applicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 CoapplicantIncome</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Coapplicant income</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 LoanAmount</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Loan amount in thousands</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Loan_Amount_Term</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Term of loan in months</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Credit_History</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 credit history meets guidelines</td>
#         </tr>
#         <tr>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-left: 0.5pt solid windowtext; border-image: initial; height: 16pt; border-top: none; min-width: 5px; user-select: text;     ">
#                 Property_Area</td>
#             <td
#                 style="color: white; font-size: 16px; font-weight: 400; font-style: normal; text-decoration: none; font-family: Times, serif; vertical-align: bottom; border-right: 0.5pt solid windowtext; border-bottom: 0.5pt solid windowtext; border-image: initial; border-top: none; border-left: none; min-width: 5px; user-select: text;     ">
#                 Urban/ Semi Urban/ Rural</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Python Code

# %%
import pandas as pd
import math
import os
import re
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
import numpy as np
import statsmodels.api as sm
from statsmodels.tools import add_constant as ac
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder, Binarizer
sc = StandardScaler()
le = LabelEncoder()
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report,  mean_squared_error, ConfusionMatrixDisplay

from imblearn.pipeline import make_pipeline as imbalanced_make_pipeline
from imblearn.pipeline import Pipeline as imbpipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
rfr = RandomForestClassifier()
# from pyforest import *
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
import warnings
warnings.filterwarnings('ignore')
from sklearn.svm import SVR
from statsmodels.formula.api import ols
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.shape
# Out:
# (614, 13)

# %%
for i in train.columns:
    if i not in test.columns:
        target_var = i
target_var
# Out:
# 'Loan_Status'

# %%
# This function would return the last created submission file with the name 
# provided(x), so that the next submission file would be named with the next 
# number automatically. 
# Like Sub1, Sub2.  

def ret_latest_file(x):
    ans = os.listdir()
    finlist = []
    re_pat = re.compile("([a-zA-Z]+)([0-9]+)")
    for i in ans:
        try:            
            if i[-3:] == 'csv':
                res = re_pat.match(i).groups()                
                if res[0] == x:
                    finlist.append(int(res[1]))            
        except:
            pass
    if len(finlist) > 0:
        return x, max(finlist)
    else:
        return x, 0

# %%
# Preparing Data for submission

def sub(n, pred):
    name, num = ret_latest_file(n)
    sol = pd.read_csv('sample_submission.csv')
    sol.loc[:, target_var] = pred
    sol.to_csv(name + '{}.csv'.format(num+1), index=False)

# %%
# Splitting combined into x_train, x_test, y_train, y_test

def split_data(df, y = target_var):

    x_train = df[df[y].notnull()]
    x_train.drop(y, inplace=True, axis=1)

    x_test = df[df[y].isnull()]
    x_test.drop(y, inplace=True, axis=1)
    y_train = df[df[y].notnull()][y]

    y_test = df[df[y].isna()][y]

    return x_train, x_test, y_train, y_test

# %%
# Implementing SMOTE

def smote(x, y):
    oversample = SMOTE(random_state = 2, sampling_strategy='minority')
    x = x.values
    y = y.values
    x, y = oversample.fit_resample(x, y)
    return x, y

# %%
# Implementing NearMiss

def near_miss(x, y):
    nr = NearMiss() 
    x_near, y_near= nr.fit_resample(x, y)
    return x_near, y_near

# %%
def cm_data(cm):
    tn = cm[0, 0]
    fp = cm[0, 1]
    fn = cm[1, 0]
    tp = cm[1, 1]
    print("Sensitivity: ", tp/(tp+fn))
    print("Specificity: ",tn/(tn+fp))
    print("Precision: ", tp/(tp+fp))
    print("Accuracy: ", (tp+tn)/(tp+tn+fp+fn))

# %%
def check_accuracy(test, pred, conf_mat = 'no'):
    acc = accuracy_score(test, pred)
    if conf_mat == 'yes':
        cm = confusion_matrix(test, pred)
        cm_df = pd.DataFrame(cm, columns=['Pred: 0', 'Pred: 1'], index = ['Obs: 0', 'Obs: 1'])
        # plt.figure(figsize=(10, 10))
        sns.heatmap(cm_df, annot=True, fmt='d')
        plt.show()
        cm_data(cm)
    return acc

# %%
def rand_search(model, params, df, samp = None, cm = 'no', subm = 'no'):

    x_train, x_test, y_train, y_test = split_data(df)
    # print(y_train.value_counts())

    if samp != None:
        if samp == 'o':
            x_train, y_train = smote(x_train, y_train)
        elif samp == 'u':
            x_train, y_train = near_miss(x_train, y_train)
        elif samp == 'b':
            x_train, y_train = smote(x_train, y_train)
            x_train, y_train = near_miss(x_train, y_train)
        x_train = pd.DataFrame(x_train)
        y_train = pd.DataFrame(y_train, columns=['Loan_Status'])

    # print(y_train.value_counts())
    x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state=123)     
    # print(y_train.value_counts())

    x_train = sc.fit_transform(x_train)
    x_test = sc.transform(x_test)

    grid_mod = RandomizedSearchCV(model, param_distributions=params, scoring = ['accuracy', 'f1'], cv = 5, n_jobs=-1, refit='accuracy')
    grid_mod.fit(x_train, y_train)

    if cm == 'yes':
        y_val_pred = grid_mod.predict(x_val)
        acc = check_accuracy(y_val, y_val_pred, conf_mat = 'yes')
    
    if subm == 'yes':
        y_pred = grid_mod.predict(x_test)
        sub(str(model)[:4], y_pred)

    return grid_mod.best_estimator_, acc

# %%
combined = pd.concat([train, test], sort=False, ignore_index=True)
combined.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             957 non-null    object
#  2   Married            978 non-null    object
#  3   Dependents         956 non-null    object
#  4   Education          981 non-null    object
#  5   Self_Employed      926 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    float64
#  10  Credit_History     902 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 99.8+ KB

# %%
# Credit History and Loan_Amount_Term should be categorical

to_be_cat = ["Credit_History", "Loan_Amount_Term"]
obj_data = list(combined.select_dtypes(['object']))
for i in obj_data:
    to_be_cat.append(i)
combined[to_be_cat] = combined[to_be_cat].astype('category')
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    category
#  1   Gender             957 non-null    category
#  2   Married            978 non-null    category
#  3   Dependents         956 non-null    category
#  4   Education          981 non-null    category
#  5   Self_Employed      926 non-null    category
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    category
#  10  Credit_History     902 non-null    category
#  11  Property_Area      981 non-null    category
#  12  Loan_Status        614 non-null    category
# dtypes: category(10), float64(2), int64(1)
# memory usage: 75.0 KB

# %%
# Base Submission
 
# sub("Base", "Y")

# %% [markdown]
# ### Univariate Analysis

# %%
not_to_plot = ["Loan_ID"]
color = ['r', 'g', 'b']

# %%
def univariate(df = combined, rows = 4, cols = 4):
    fig=plt.figure(figsize=(20,20))
    for j, i in enumerate(df.columns):
        if i not in not_to_plot:
            ax=fig.add_subplot(rows,cols,j+1)
            if i in df.select_dtypes(['category', 'object']):
                sns.countplot(x= i, data = df, ax=ax)
                plt.xticks(rotation = 90)
            if i in df.select_dtypes(['int', 'float64']):
                sns.distplot(x = df[i], ax=ax, color=np.random.choice(color))
                ax.set(xlabel=i)
    fig.tight_layout() 
    plt.show()

# %%
univariate()

# %% [markdown]
# #### Insights:
#
# 1. In **Loan Status** column, high Imbalance exists. Could try Balancing it with *SMOTE*.
# 2. In **Loan Amount Term** column, Maximum People(800) are taking loan for 30 years (360 months). Could be Huge loans like Car loans or Home Loans.
# 3. In **Gender** column, Male Applicants are quite higher than Female Applicants.
#
#     3.1 Male Applicants could be from Urban, Semi Urban and Rural areas.
#
#     3.2 Female Applicants could be just from Urban Areas.

# %% [markdown]
# ### Bivariate Analysis

# %%
def bivariate(df = combined, y = target_var, cols = 4, rows = 3):
    temp = not_to_plot[:]
    temp.append(y)
    fig=plt.figure(figsize=(25,20))

    for j, i in enumerate(df.columns):
        if i not in temp:
            if df[y].dtype == 'float':
                if i in df.select_dtypes(['category', 'object']):
                    if (i not in temp): 
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.boxplot(x = i, y = y, data = df)
                        plt.xticks(rotation = 90)

                if i in df.select_dtypes(['float', 'int']):                
                    if (i not in temp):      
                        ax=fig.add_subplot(rows,cols,j+1)       
                        sns.scatterplot(x = y, y = i, data = df)                  
                
            elif df[y].dtype == 'category':
                if i in df.select_dtypes(['category', 'object']):
                    if (i not in temp):
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.countplot(x = i, hue = y, data = df)
                        plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
                        plt.xticks(rotation = 90)

                if i in df.select_dtypes(['float', 'int']):
                    if (i not in temp):
                        ax=fig.add_subplot(rows,cols,j+1)
                        sns.boxplot(x = y, y = i, data = df)
                        plt.xticks(rotation = 90)
    fig.tight_layout() 
    plt.show()

# %%
bivariate()

# %% [markdown]
# ### Missing Values

# %%
combined.isnull().sum()[combined.isnull().sum()>0]
# Out:
# Gender               24
# Married               3
# Dependents           25
# Self_Employed        55
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Loan_Status         367
# dtype: int64

# %% [markdown]
# #### Solution 1: Drop All Null Values and Create a model.

# %%
# combined.dropna(subset= combined.columns[combined.columns != target_var], inplace=True)

# %%
combined.isnull().sum()[combined.isnull().sum()>0]
# Out:
# Gender               24
# Married               3
# Dependents           25
# Self_Employed        55
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Loan_Status         367
# dtype: int64

# %%
combined["Gender"].isnull().sum()
# Out:
# 24

# %% [markdown]
# Dropping Null Values leads to removal of some Test data.
#
# Can't Drop Null Values.

# %% [markdown]
# #### Solution 2: Fill All Null Values with Mean, Mode of the columns.

# %%
def fill_na(df = combined):
    for i in df.columns:
        if i != target_var:
            if df[i].isnull().sum() > 0:
                if i in df.select_dtypes(["category", "object"]):
                    df[i].fillna(df.mode()[i][0], inplace = True)
                elif i in df.select_dtypes(["int", "float"]):
                    df[i].fillna(df[i].mean(), inplace = True)
    print(df.isnull().sum()[df.isnull().sum()>0])
    return df

# %%
combined = fill_na()
# Out:
# Loan_Status    367
# dtype: int64

# %% [markdown]
# #### Solution 3: Find Pattern for all columns and fill null values.

# %% [markdown]
# ##### Gender - 24

# %%
combined.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 0             5849                0.0   142.51153            360.0
# 1             4583             1508.0   128.00000            360.0
# 2             3000                0.0    66.00000            360.0
# 3             2583             2358.0   120.00000            360.0
# 4             6000                0.0   141.00000            360.0
#
#   Credit_History Property_Area Loan_Status
# 0            1.0         Urban           Y
# 1            1.0         Rural           N
# ...

# %%
combined.loc[:, ["Gender", "LoanAmount", "ApplicantIncome", "CoapplicantIncome", "Property_Area"]].sample(10)
# Out:
#      Gender  LoanAmount  ApplicantIncome  CoapplicantIncome Property_Area
# 37   Female       144.0             3667             1459.0     Semiurban
# 953  Female       162.0             4333             2333.0         Rural
# 815    Male        90.0             2855              542.0         Urban
# 705    Male       390.0            13518                0.0         Rural
# 20     Male       104.0             7660                0.0         Urban
# 516  Female       113.0             2031             1632.0     Semiurban
# 298  Female       151.0             5000             2541.0         Rural
# 730  Female       180.0                0             1760.0     Semiurban
# 892    Male       176.0             3634              910.0     Semiurban
# 491    Male       186.0             5333             1131.0         Urban

# %% [markdown]
# #### Self Employed

# %%
combined.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 849  LP002316    Male      No          0      Graduate            No
# 305  LP001990    Male      No          0  Not Graduate            No
# 856  LP002344    Male     Yes          0      Graduate            No
# 319  LP002050    Male     Yes          1      Graduate           Yes
# 974  LP002965  Female     Yes          0      Graduate            No
# 887  LP002495    Male     Yes          2      Graduate            No
# 70   LP001243    Male     Yes          0      Graduate            No
# 926  LP002754    Male      No          0      Graduate            No
# 752  LP001769    Male      No          0      Graduate            No
# 545  LP002767    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 849             2231             2774.0   176.00000            360.0
# ...

# %%
combined[combined.Self_Employed.notnull()].sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 361  LP002170    Male     Yes          2      Graduate            No
# 131  LP001473    Male      No          0      Graduate            No
# 261  LP001868    Male      No          0      Graduate            No
# 530  LP002717    Male     Yes          0      Graduate            No
# 875  LP002420    Male     Yes          0      Graduate            No
# 301  LP001972    Male     Yes          0  Not Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 861  LP002360    Male     Yes          0      Graduate            No
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 954  LP002860    Male     Yes          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 361             5000             3667.0   236.00000            360.0
# ...

# %% [markdown]
# ### Feature Engineering

# %%
combined.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 197  LP001669  Female      No          0  Not Graduate            No
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 660  LP001237    Male     Yes          0  Not Graduate            No
# 939  LP002802    Male      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 922  LP002744    Male     Yes          1      Graduate            No
# 973  LP002962    Male      No          0      Graduate            No
# 662  LP001268    Male      No          0      Graduate            No
# 447  LP002435    Male     Yes          0      Graduate            No
# 245  LP001813    Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Loan_Amount_Term  \
# 197             1907             2365.0       120.0            360.0
# ...

# %%
combined_feat = combined[:]

# %%
# Could try adding Applicant Income and Co-Applicant Income to create Household Income.

combined_feat['House_Income'] = combined_feat["ApplicantIncome"] + combined_feat["CoapplicantIncome"] 
combined_feat.drop(["ApplicantIncome", "CoapplicantIncome"], axis = 1, inplace=True)
combined_feat.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 278  LP001907    Male     Yes          0      Graduate            No
# 823  LP002165    Male      No          1  Not Graduate            No
# 110  LP001385    Male      No          0      Graduate            No
# 419  LP002347    Male     Yes          0      Graduate            No
# 957  LP002870    Male     Yes          1      Graduate            No
# 194  LP001664    Male      No          0      Graduate            No
# 434  LP002390    Male      No          0      Graduate            No
# 622  LP001059    Male     Yes          2      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 907  LP002609  Female     Yes          0      Graduate            No
#
#      LoanAmount Loan_Amount_Term Credit_History Property_Area Loan_Status  \
# 278       436.0            360.0            1.0     Semiurban           Y
# ...

# %%
combined.Loan_Amount_Term.value_counts()
# Out:
# 360.0    843
# 180.0     66
# 480.0     23
# 300.0     20
# 240.0      8
# 84.0       7
# 120.0      4
# 36.0       3
# 60.0       3
# 12.0       2
# 6.0        1
# 350.0      1
# Name: Loan_Amount_Term, dtype: int64

# %%
# Could try converting Term into years.
from numpy import int64

combined_feat["Loan_Amount_Term"] = combined_feat["Loan_Amount_Term"].astype(int64)
combined_feat["Loan_Term"] = combined_feat["Loan_Amount_Term"] / 12
combined_feat.drop(["Loan_Amount_Term"], axis = 1, inplace=True)
combined_feat["Loan_Term"] = combined_feat["Loan_Term"].astype(int64)
combined_feat["Loan_Term"] = combined_feat["Loan_Term"].astype("category")
combined_feat.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 347  LP002131    Male     Yes          2  Not Graduate            No
# 26   LP001068    Male     Yes          0      Graduate            No
# 926  LP002754    Male      No          0      Graduate            No
# 618  LP001051    Male      No          0  Not Graduate            No
# 567  LP002837    Male     Yes         3+      Graduate            No
# 268  LP001883  Female      No          0      Graduate            No
# 720  LP001563    Male      No          0      Graduate            No
# 143  LP001507    Male     Yes          0      Graduate            No
# 519  LP002684  Female      No          0  Not Graduate            No
# 384  LP002236    Male     Yes          2      Graduate            No
#
#      LoanAmount Credit_History Property_Area Loan_Status  House_Income  \
# 347       126.0            1.0         Urban           Y        5251.0
# ...

# %%
combined_feat.drop(["Loan_ID"], axis = 1, inplace=True)
combined_feat.sample(10)
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 328  Female     Yes          0      Graduate            No       110.0
# 796    Male     Yes          2      Graduate            No       110.0
# 16     Male      No          1  Not Graduate            No       100.0
# 831    Male     Yes          0      Graduate            No       212.0
# 767    Male     Yes          1  Not Graduate            No       117.0
# 957    Male     Yes          1      Graduate            No        80.0
# 345    Male     Yes          0      Graduate            No       160.0
# 601    Male     Yes          0  Not Graduate            No       155.0
# 344    Male     Yes          2      Graduate            No       125.0
# 28     Male      No          0  Not Graduate            No        35.0
#
#     Credit_History Property_Area Loan_Status  House_Income Loan_Term
# 328            1.0         Urban           N        6784.0        30
# ...

# %% [markdown]
# #### Encoding

# %%
combined_en = combined_feat[:]

# %% [markdown]
# ##### Label Encoding

# %%
lb_en = ["Loan_Term"]

# %%
combined_en[lb_en] = combined_en[lb_en].apply(LabelEncoder().fit_transform)
combined_en.sample(5)
# Out:
#      Gender Married Dependents     Education Self_Employed  LoanAmount  \
# 707    Male     Yes          2  Not Graduate            No       100.0
# 65     Male     Yes          0      Graduate            No       258.0
# 556  Female      No          0      Graduate            No        84.0
# 888  Female      No          0      Graduate            No        94.0
# 200    Male     Yes          1  Not Graduate            No        90.0
#
#     Credit_History Property_Area Loan_Status  House_Income  Loan_Term
# 707            1.0     Semiurban         NaN        6412.0         10
# 65             1.0     Semiurban           N       10321.0         10
# 556            1.0         Urban           Y        4292.0         10
# 888            0.0     Semiurban         NaN        3500.0         10
# 200            1.0     Semiurban           Y        5100.0         10

# %%
combined_en["Loan_Status"].replace(to_replace = {'Y': 1, 'N': 0}, inplace = True)

# %%
combined_en.Loan_Status.value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %% [markdown]
# ##### Get Dummies

# %%
gd_dm = ["Gender", "Married", "Dependents", "Education", "Self_Employed", "Credit_History", "Property_Area"]

# %%
combined_en = pd.get_dummies(data = combined_en, columns = gd_dm, drop_first=True)
combined_en.sample(5)
# Out:
#      LoanAmount Loan_Status  House_Income  Loan_Term  Gender_Male  \
# 629       131.0         NaN        5667.0         10            1
# 831       212.0         NaN       10013.0         10            1
# 713       188.0         NaN        6835.0         10            1
# 807       128.0         NaN        4652.0         10            1
# 630       200.0         NaN        7499.0         10            1
#
#      Married_Yes  Dependents_1  Dependents_2  Dependents_3+  \
# 629            0             1             0              0
# 831            1             0             0              0
# 713            1             0             0              1
# 807            1             0             0              1
# 630            1             0             1              0
#
#      Education_Not Graduate  Self_Employed_Yes  Credit_History_1.0  \
# 629                       0                  0                   1
# 831                       0                  0                   1
# ...

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### 1. Logistic Regression

# %%
x = combined_feat.loc[combined_feat["Loan_Status"].notnull(), combined_feat.columns != target_var]
y = combined_feat.loc[combined_feat["Loan_Status"].notnull(), target_var]

x = x.apply(LabelEncoder().fit_transform)

y.replace(to_replace = {'Y': 1, 'N': 0}, inplace = True)

# print(y)

model = sm.Logit(y, ac(x))
res = model.fit()

print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466397
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:            Loan_Status   No. Observations:                  614
# Model:                          Logit   Df Residuals:                      603
# Method:                           MLE   Df Model:                           10
# Date:                Fri, 09 Sep 2022   Pseudo R-squ.:                  0.2493
# Time:                        15:26:30   Log-Likelihood:                -286.37
# converged:                       True   LL-Null:                       -381.45
# Covariance Type:            nonrobust   LLR p-value:                 1.815e-35
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.6347      0.925     -2.848      0.004      -4.448      -0.822
# ...

# %%
# Removing cols with p-value more than 0.05

def back_feat_elem(df = combined_feat, y = target_var):
    x = df.loc[combined_en["Loan_Status"].notnull(), df.columns != y]
    y = df.loc[combined_en["Loan_Status"].notnull(), y]

    x = x.apply(LabelEncoder().fit_transform)
    y.replace(to_replace = {'Y': 1, 'N': 0}, inplace = True)

    col = x.columns

    while len(col) > 0:
        model = sm.Logit(y, ac(x[col]))
        result = model.fit(disp= 0)
        largest_pvalue = round(result.pvalues, 3).nlargest(1)
        if largest_pvalue[0] < (0.05):
            return result
            break
        else:
            col = col.drop(largest_pvalue.index)

# %%
# back_res = back_feat_elem()
# back_res.summary()

# %% [markdown]
# #### 2. Decision Tree Classifier

# %%
params_dt = {
    'criterion': ['gini','entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [3, 6, 9],
    'min_samples_leaf': [5, 8, 11],
    'max_features': ['sqrt', 'log2'],
}

# %%
mod_dt_o, acc_dt_o = rand_search(model = DecisionTreeClassifier(), params = params_dt, df = combined_en, cm = 'yes', samp = 'o')
# Out:
# Sensitivity:  0.6363636363636364
# Specificity:  0.7530864197530864
# Precision:  0.7368421052631579
# Accuracy:  0.6923076923076923

# %% [markdown]
# #### 3. Random Forest Classifier

# %%
rf_params = {
    'n_estimators': [10, 50, 100, 150, 200],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [10, 15, 20, 25, 40],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True, False],
    'oob_score': [True],
    'n_jobs': [3],
}

# %%
mod_rf_o, acc_rf_o = rand_search(model=RandomForestClassifier(), params=rf_params, df = combined_en, samp='o', cm='yes')
# Out:
# Sensitivity:  0.0
# Specificity:  1.0
# Precision:  nan
# Accuracy:  0.47928994082840237

# %% [markdown]
# #### 4. KNN Classification

# %%
params_knn = {
    'n_neighbors': [1, 3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'n_jobs': [-1],
    'p':[0,1,2,i]
}

# %%
mod_knn_o, acc_knn_o = rand_search(model = KNeighborsClassifier(), params = params_knn, df = combined_en, cm='yes', samp = 'o')
# Out:
# Sensitivity:  0.9545454545454546
# Specificity:  0.19753086419753085
# Precision:  0.5637583892617449
# Accuracy:  0.591715976331361

# %%
combined_en.shape
# Out:
# (981, 14)

# %% [markdown]
# #### 5. Deep Learning

# %%
def model_dl():
  model = Sequential()
  model.add(Dense(20, input_shape=(13,), activation='relu'))
  model.add(Dense(15, activation='relu'))
  model.add(Dense(15, activation='relu'))
  model.add(Dense(1, activation = 'sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
  return model

# %%
params_dl = {
    'nb_epoch': [20, 40, 60, 80, 100],
    'batch_size': [8, 16, 32]
}

# %%
model=KerasClassifier(build_fn=model_dl, validation_data = (x_val, y_val), verbose = 2)

# %%
mod_dl_o, acc_dl_o = rand_search(model = model, params = params_dl, df = combined_en, cm='yes', samp = 'o')
# Out:
# 85/85 - 2s - loss: 0.6952 - accuracy: 0.5289 - val_loss: 0.6494 - val_accuracy: 0.6864 - 2s/epoch - 23ms/step
# 6/6 [==============================] - 0s 3ms/step
# Sensitivity:  1.0
# Specificity:  0.0
# Precision:  0.5207100591715976
# Accuracy:  0.5207100591715976

# %%
x, x_test, y, y_test = split_data(combined_en)

x, y = smote(x, y)
x = pd.DataFrame(x)
y = pd.DataFrame(y)

x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = 0.2, random_state = 123)


x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_val = sc.transform(x_val)

model = KerasClassifier(build_fn=model_dl, epochs = 100, validation_data = (x_val, y_val), batch_size = 16, verbose=0)
model.fit(x_train, y_train)

pred = model.predict(x_test)
y_val_pred = model.predict(x_val)

acc = check_accuracy(y_val, y_val_pred, conf_mat = 'yes')
# Out:
# ...
# 6/6 [==============================] - 0s 3ms/step
# Sensitivity:  0.75
# Specificity:  0.7777777777777778
# Precision:  0.7857142857142857
# Accuracy:  0.7633136094674556

# %%
pred = pred.astype('object')
pred[pred == 0] = 'N'
pred[pred == 1] = 'Y'
# sub("DL", pred)
